# %%
pip install pandas matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\Users\My Pc\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.2.3)Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\My Pc\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\My Pc\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\My Pc\AppData\Roaming\Python\Python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\My Pc\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\My Pc\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2024.2)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in C:\Users\My Pc\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\My Pc\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 799.2 kB/s eta 0:00:10
#    --- ------------------------------------ 0.8/8.1 MB 958.5 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/8.1 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/8.1 MB 1.1 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.1 MB 1.1 MB/s eta 0:00:06
#    --------- ------------------------------ 1.8/8.1 MB 1.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.1/8.1 MB 1.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.4/8.1 MB 1.1 MB/s eta 0:00:06
#    ------------ --------------------------- 2.6/8.1 MB 1.1 MB/s eta 0:00:05
#    ------------ --------------------------- 2.6/8.1 MB 1.1 MB/s eta 0:00:05
#    -------------- ------------------------- 2.9/8.1 MB 1.1 MB/s eta 0:00:05
#    --------------- ------------------------ 3.1/8.1 MB 1.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 3.4/8.1 MB 1.1 MB/s eta 0:00:05
#    ------------------ --------------------- 3.7/8.1 MB 1.1 MB/s eta 0:00:04
#    ------------------- -------------------- 3.9/8.1 MB 1.1 MB/s eta 0:00:04
#    -------------------- ------------------- 4.2/8.1 MB 1.1 MB/s eta 0:00:04
#    --------------------- ------------------ 4.5/8.1 MB 1.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 4.7/8.1 MB 1.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 4.7/8.1 MB 1.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 4.7/8.1 MB 1.1 MB/s eta 0:00:04
#    ------------------------ --------------- 5.0/8.1 MB 1.0 MB/s eta 0:00:04
#    ------------------------- -------------- 5.2/8.1 MB 1.1 MB/s eta 0:00:03
#    --------------------------- ------------ 5.5/8.1 MB 1.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 5.8/8.1 MB 1.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 6.0/8.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.1 MB 1.1 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.1 MB 1.1 MB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.1 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 7.1/8.1 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 1.1 MB/s  0:00:07
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 1.0 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.0 MB/s eta 0:00:02
#    -------------------------- ------------- 1.6/2.3 MB 814.6 kB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 860.4 kB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 860.4 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 883.1 kB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 888.9 kB/s  0:00:02
# Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 1.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 0.8/7.0 MB 1.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 0.8/7.0 MB 1.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/7.0 MB 1.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/7.0 MB 1.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/7.0 MB 1.0 MB/s eta 0:00:06
#    ------- -------------------------------- 1.3/7.0 MB 753.8 kB/s eta 0:00:08
#    -------- ------------------------------- 1.6/7.0 MB 791.5 kB/s eta 0:00:07
#    -------- ------------------------------- 1.6/7.0 MB 791.5 kB/s eta 0:00:07
#    -------- ------------------------------- 1.6/7.0 MB 791.5 kB/s eta 0:00:07
#    ---------- ----------------------------- 1.8/7.0 MB 703.7 kB/s eta 0:00:08
#    ----------- ---------------------------- 2.1/7.0 MB 699.0 kB/s eta 0:00:08
#    ----------- ---------------------------- 2.1/7.0 MB 699.0 kB/s eta 0:00:08
#    ------------- -------------------------- 2.4/7.0 MB 691.9 kB/s eta 0:00:07
#    ------------- -------------------------- 2.4/7.0 MB 691.9 kB/s eta 0:00:07
#    ------------- -------------------------- 2.4/7.0 MB 691.9 kB/s eta 0:00:07
#    -------------- ------------------------- 2.6/7.0 MB 674.1 kB/s eta 0:00:07
#    -------------- ------------------------- 2.6/7.0 MB 674.1 kB/s eta 0:00:07
#    -------------- ------------------------- 2.6/7.0 MB 674.1 kB/s eta 0:00:07
#    -------------- ------------------------- 2.6/7.0 MB 674.1 kB/s eta 0:00:07
#    ---------------- ----------------------- 2.9/7.0 MB 590.7 kB/s eta 0:00:08
#    ----------------- ---------------------- 3.1/7.0 MB 615.1 kB/s eta 0:00:07
#    ----------------- ---------------------- 3.1/7.0 MB 615.1 kB/s eta 0:00:07
#    ------------------- -------------------- 3.4/7.0 MB 615.6 kB/s eta 0:00:06
#    ------------------- -------------------- 3.4/7.0 MB 615.6 kB/s eta 0:00:06
#    -------------------- ------------------- 3.7/7.0 MB 605.8 kB/s eta 0:00:06
#    -------------------- ------------------- 3.7/7.0 MB 605.8 kB/s eta 0:00:06
#    -------------------- ------------------- 3.7/7.0 MB 605.8 kB/s eta 0:00:06
#    ---------------------- ----------------- 3.9/7.0 MB 600.7 kB/s eta 0:00:06
#    ---------------------- ----------------- 3.9/7.0 MB 600.7 kB/s eta 0:00:06
#    ----------------------- ---------------- 4.2/7.0 MB 597.8 kB/s eta 0:00:05
#    ----------------------- ---------------- 4.2/7.0 MB 597.8 kB/s eta 0:00:05
#    ------------------------- -------------- 4.5/7.0 MB 591.2 kB/s eta 0:00:05
#    ------------------------- -------------- 4.5/7.0 MB 591.2 kB/s eta 0:00:05
#    -------------------------- ------------- 4.7/7.0 MB 596.7 kB/s eta 0:00:04
#    -------------------------- ------------- 4.7/7.0 MB 596.7 kB/s eta 0:00:04
#    ---------------------------- ----------- 5.0/7.0 MB 599.2 kB/s eta 0:00:04
#    ---------------------------- ----------- 5.0/7.0 MB 599.2 kB/s eta 0:00:04
#    ----------------------------- ---------- 5.2/7.0 MB 601.5 kB/s eta 0:00:03
#    ----------------------------- ---------- 5.2/7.0 MB 601.5 kB/s eta 0:00:03
#    ------------------------------- -------- 5.5/7.0 MB 599.2 kB/s eta 0:00:03
#    ------------------------------- -------- 5.5/7.0 MB 599.2 kB/s eta 0:00:03
#    ------------------------------- -------- 5.5/7.0 MB 599.2 kB/s eta 0:00:03
#    -------------------------------- ------- 5.8/7.0 MB 590.2 kB/s eta 0:00:03
#    ---------------------------------- ----- 6.0/7.0 MB 595.3 kB/s eta 0:00:02
#    ---------------------------------- ----- 6.0/7.0 MB 595.3 kB/s eta 0:00:02
#    ---------------------------------- ----- 6.0/7.0 MB 595.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 6.3/7.0 MB 586.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 6.3/7.0 MB 586.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 6.3/7.0 MB 586.5 kB/s eta 0:00:02
#    ------------------------------------- -- 6.6/7.0 MB 578.5 kB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 578.5 kB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 578.5 kB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 573.0 kB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 573.0 kB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 566.5 kB/s  0:00:12
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ---------- ----------------------------- 2/8 [kiwisolver]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    -------------------- ------------------- 4/8 [cycler]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ---------------------------------------- 8/8 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2 seaborn-0.13.2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("iris")

# %%
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(df.shape)
# Out:
# (150, 5)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
print(df.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.scatterplot(x="sepal_length", y="petal_length", data=df)

plt.show()

# %%
df["sepal_length"].hist()

plt.show()

# %%
sns.boxplot(x=df["sepal_length"])

plt.show()
